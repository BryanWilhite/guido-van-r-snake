# %% [markdown]
# # Python Programming Tutorials (Computer Science)
#
# The 🦉 [Socratica](https://www.youtube.com/channel/UCW6TXMZ5Pq6yL6_k5NZ2e0Q) YouTube Channel has a 33-video [playlist](https://www.youtube.com/playlist?list=PLi01XoE8jYohWFPpC17Z-wWhPOSuh8Er-) devoted to the introduction of Python.
#
# ## #19 Python Random Number Generator: the Random Module

# %%
# %run video-00.py

# %%
from IPython import display

video = display.YouTubeVideo('zWL3z7NMqAs')
video
display.HTML(f'<a href="{video.src}">link</a>')
# Out:
# <a href="https://www.youtube.com/embed/zWL3z7NMqAs">link</a>

# %% [markdown]
# Python offers a pseudo-random number generator in the `random` module [📖 [docs](https://docs.python.org/3/library/random.html)]:

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_BuiltinMethodType',
#  '_MethodType',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_itertools',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
for i in range(10):
    print(random.random()) # interval [0, 1)
# Out:
# 0.8760932879443015
# 0.7804489471844009
# 0.8933430445465976
# 0.19092896111752167
# 0.8885382819998233
# 0.7987585357251861
# 0.840285734315765
# 0.7691309474680258
# 0.958240970033405
# 0.35691151756976847

# %% [markdown]
# The documentation warns us:
#
# >The pseudo-random generators of this module should not be used for security purposes. For security or cryptographic uses, see the `secrets` module.
#
# We see that `.random()` pulls from the interval $[0, 1)$ by default. Let us specify a different interval with our own function:

# %%
def my_random(floor, max):
    interval = max - floor
    return interval * random.random() + floor

# %%
for i in range(10):
    print(my_random(3, 7)) # interval [3, 7)
# Out:
# 3.389598651388087
# 3.1606901776313205
# 3.543299007754413
# 4.676473925061591
# 3.461491026447123
# 3.4759446269417293
# 6.354710966512478
# 4.953245916837799
# 4.6189031102248475
# 6.6144797070642625

# %% [markdown]
# Python gives us the `.uniform()` function as the equivalent of our function above:

# %%
help(random.uniform)
# Out:
# Help on method uniform in module random:
#
# uniform(a, b) method of random.Random instance
#     Get a random number in the range [a, b) or [a, b] depending on rounding.

# %%
for i in range(10):
    print(random.uniform(3, 7)) # interval [3, 7)
# Out:
# 6.114951842233568
# 3.3317765709604372
# 4.131977772146028
# 4.199215365698317
# 4.074985279886047
# 5.303634240324678
# 4.55025892266506
# 5.1700805460161625
# 5.342834913048103
# 3.262468855675449

# %% [markdown]
# The reason why `.uniform()` has its name is to remind us that number genration is within a [uniform distribution](https://en.wikipedia.org/wiki/Uniform_distribution_(continuous)) of possible values. The distribution of `.random()` is also uniform.
#
# For a [normal distribution](https://en.wikipedia.org/wiki/Normal_distribution), we have the `.normalvariate()` function:

# %%
help(random.normalvariate)
# Out:
# Help on method normalvariate in module random:
#
# normalvariate(mu, sigma) method of random.Random instance
#     Normal distribution.
#
#     mu is the mean, and sigma is the standard deviation.

# %%
# %%html
# <img src="./video-19.png" />
# Out:
# <img src="./video-19.png" />

# %%
for i in range(20):
    print(random.normalvariate(0, 9))
# Out:
# -3.0893899268913776
# -20.694264251067153
# -10.812484114829301
# -3.932542273016107
# -0.494839492134347
# 23.058073201415137
# 9.319441848495064
# -10.080165363380633
# 12.282236016671913
# -25.23618617527141
# -9.649063690616149
# -6.641300294087149
# -2.007207225622748
# 7.8802333610573845
# -4.258247802764826
# 16.714434732258287
# 3.235116140747933
# -10.268175758278492
# 11.071118835952877
# -1.91783403159859

# %%
for i in range(20):
    print(random.normalvariate(5, .2))
# Out:
# 4.975321576894175
# 4.78191544386589
# 5.1860982832151095
# 4.9820001885186995
# 4.77147621518044
# 5.066910082871097
# 5.089945461254418
# 4.94296372229916
# 4.562567829972504
# 5.279918471412102
# 4.53194462119882
# 5.206026093376115
# 4.942273403530911
# 4.98733688663605
# 4.958383264072159
# 5.1592357419194474
# 5.192788530843851
# 5.1100658625570095
# 5.353178227248731
# 5.256285944704443

# %% [markdown]
# ### Discrete Probability Distributions
#
# To generate `int` instead of `float` numbers, we have [discrete distributions](https://en.wikipedia.org/wiki/List_of_probability_distributions#Discrete_distributions) generated by `.randint()`:

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
for i in range(20):
    print(random.randint(1, 6))
# Out:
# 5
# 6
# 5
# 4
# 6
# 3
# 3
# 5
# 5
# 2
# 5
# 6
# 2
# 3
# 2
# 4
# 1
# 6
# 4
# 1

# %% [markdown]
# To randomly select an item from a sequence, we have `.choice()`:

# %%
help(random.choice)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %%
for i in range(10):
    print(random.choice(['rock', 'paper', 'scissors']))
# Out:
# paper
# paper
# rock
# paper
# scissors
# rock
# rock
# paper
# scissors
# paper

# %%
for i in range(10):
    print(random.choice(('rock', 'paper', 'scissors')))
# Out:
# scissors
# paper
# paper
# rock
# scissors
# rock
# rock
# scissors
# paper
# rock

# %%
for i in range(10):
    print(random.choice({0:'rock', 1:'paper', 2:'scissors'}))
# Out:
# paper
# paper
# paper
# paper
# scissors
# rock
# paper
# rock
# scissors
# scissors

# %%
for i in range(10):
    print(random.choice(set(['rock', 'paper', 'scissors'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-91513ee8d40b> in <module>
#       1 for i in range(10):
# ----> 2     print(random.choice(set(['rock', 'paper', 'scissors'])))
#
# C:\tools\Anaconda3\lib\random.py in choice(self, seq)
#     260         except ValueError:
#     261             raise IndexError('Cannot choose from an empty sequence') from None
# --> 262         return seq[i]
#     263
#     264     def shuffle(self, x, random=None):
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# _Reminder:_ a `set` is not a sequence.
